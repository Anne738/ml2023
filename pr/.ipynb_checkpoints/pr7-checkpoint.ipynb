# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt

# %%
# бінарна класифікація
X_binary, y_binary = make_classification(n_samples=5000, n_features=2, n_informative=2, n_redundant=0, random_state=42)

binary_classification_data = pd.DataFrame(data=X_binary, columns=[f'Attribute{i}' for i in range(1, 3)])
binary_classification_data['Label'] = y_binary

# мультикласова класифікація
X_multiclass, y_multiclass = make_classification(n_samples=5000, n_classes=3, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=42)

multiclass_classification_data = pd.DataFrame(data=X_multiclass, columns=[f'Attribute{i}' for i in range(1, 3)])
multiclass_classification_data['Label'] = y_multiclass


# розділяємо дані на тренувальний та тестовий набори
X_binary_train, X_binary_test, y_binary_train, y_binary_test = train_test_split(X_binary, y_binary, test_size=0.2, random_state=42)
X_multiclass_train, X_multiclass_test, y_multiclass_train, y_multiclass_test = train_test_split(X_multiclass, y_multiclass, test_size=0.2, random_state=42)

# %%
# Для бінарної класифікації
model_binary = Sequential([
    Dense(32, input_dim=2, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')   
])

model_binary.compile(optimizer='adam', 
                     loss='binary_crossentropy', 
                     metrics=['accuracy'])

history_binary = model_binary.fit(X_binary_train, y_binary_train, epochs=50, batch_size=8, validation_data=(X_binary_test, y_binary_test))

# Для мультикласової класифікації
model_multiclass = Sequential([
    Dense(32, input_dim=2, activation='relu'),
    Dense(16, activation='relu'),
    Dense(3, activation='softmax')  
])

model_multiclass.compile(optimizer='adam', 
                         loss='sparse_categorical_crossentropy', 
                         metrics=['accuracy'])

history_multiclass = model_multiclass.fit(X_multiclass_train, y_multiclass_train, epochs=50, batch_size=8, validation_data=(X_multiclass_test, y_multiclass_test))
# Out:
# Epoch 1/50
# 500/500 [==============================] - 2s 2ms/step - loss: 0.3485 - accuracy: 0.8525 - val_loss: 0.2980 - val_accuracy: 0.8780
# Epoch 2/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2858 - accuracy: 0.8755 - val_loss: 0.2790 - val_accuracy: 0.8890
# Epoch 3/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2636 - accuracy: 0.8838 - val_loss: 0.2581 - val_accuracy: 0.8900
# Epoch 4/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2465 - accuracy: 0.8963 - val_loss: 0.2483 - val_accuracy: 0.8970
# Epoch 5/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2349 - accuracy: 0.9078 - val_loss: 0.2381 - val_accuracy: 0.9040
# Epoch 6/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2284 - accuracy: 0.9118 - val_loss: 0.2307 - val_accuracy: 0.9080
# Epoch 7/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2221 - accuracy: 0.9137 - val_loss: 0.2253 - val_accuracy: 0.9110
# Epoch 8/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2188 - accuracy: 0.9135 - val_loss: 0.2271 - val_accuracy: 0.9100
# Epoch 9/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2153 - accuracy: 0.9153 - val_loss: 0.2247 - val_accuracy: 0.9170
# Epoch 10/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2153 - accuracy: 0.9147 - val_loss: 0.2202 - val_accuracy: 0.9160
# Epoch 11/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2128 - accuracy: 0.9183 - val_loss: 0.2207 - val_accuracy: 0.9100
# Epoch 12/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2118 - accuracy: 0.9170 - val_loss: 0.2243 - val_accuracy: 0.9150
# Epoch 13/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2119 - accuracy: 0.9193 - val_loss: 0.2212 - val_accuracy: 0.9090
# Epoch 14/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2094 - accuracy: 0.9175 - val_loss: 0.2195 - val_accuracy: 0.9090
# Epoch 15/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2093 - accuracy: 0.9193 - val_loss: 0.2185 - val_accuracy: 0.9110
# Epoch 16/50
# 500/500 [==============================] - 2s 3ms/step - loss: 0
50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2761 - accuracy: 0.8855 - val_loss: 0.3044 - val_accuracy: 0.8820
# Epoch 32/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2746 - accuracy: 0.8857 - val_loss: 0.2890 - val_accuracy: 0.8990
# Epoch 33/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2758 - accuracy: 0.8882 - val_loss: 0.2856 - val_accuracy: 0.8980
# Epoch 34/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2733 - accuracy: 0.8898 - val_loss: 0.2816 - val_accuracy: 0.8960
# Epoch 35/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2727 - accuracy: 0.8895 - val_loss: 0.2871 - val_accuracy: 0.8950
# Epoch 36/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2739 - accuracy: 0.8892 - val_loss: 0.2859 - val_accuracy: 0.8950
# Epoch 37/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2722 - accuracy: 0.8870 - val_loss: 0.2939 - val_accuracy: 0.8890
# Epoch 38/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2724 - accuracy: 0.8875 - val_loss: 0.2877 - val_accuracy: 0.8950
# Epoch 39/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2717 - accuracy: 0.8888 - val_loss: 0.2873 - val_accuracy: 0.8980
# Epoch 40/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2720 - accuracy: 0.8875 - val_loss: 0.2885 - val_accuracy: 0.8960
# Epoch 41/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2715 - accuracy: 0.8890 - val_loss: 0.2832 - val_accuracy: 0.8920
# Epoch 42/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2736 - accuracy: 0.8863 - val_loss: 0.2906 - val_accuracy: 0.8920
# Epoch 43/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2709 - accuracy: 0.8875 - val_loss: 0.2894 - val_accuracy: 0.8960
# Epoch 44/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2717 - accuracy: 0.8882 - val_loss: 0.2877 - val_accuracy: 0.8910
# Epoch 45/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2718 - accuracy: 0.8885 - val_loss: 0.2853 - val_accuracy: 0.8960
# Epoch 46/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2709 - accuracy: 0.8878 - val_loss: 0.2809 - val_accuracy: 0.8960
# Epoch 47/50
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2697 - accuracy: 0.8882 - val_loss: 0.2901 - val_accuracy: 0.8940
# Epoch 48/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2716 - accuracy: 0.8900 - val_loss: 0.2832 - val_accuracy: 0.8950
# Epoch 49/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2701 - accuracy: 0.8885 - val_loss: 0.2878 - val_accuracy: 0.8930
# Epoch 50/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2699 - accuracy: 0.8898 - val_loss: 0.2897 - val_accuracy: 0.8980

# %%
# оцінка ефективності моделі на тестовому наборі
test_loss, test_acc = model_binary.evaluate(X_binary_test, y_binary_test, verbose=2)
print('\nТочність бінарної на тестовому наборі:', test_acc, '\n')

test_loss, test_acc = model_multiclass.evaluate(X_multiclass_test, y_multiclass_test, verbose=2)
print('\nТочність мультикласової на тестовому наборі:', test_acc)
# Out:
# 32/32 - 0s - loss: 0.2126 - accuracy: 0.9150 - 145ms/epoch - 5ms/step
#
# Точність бінарної на тестовому наборі: 0.9150000214576721
#
# 32/32 - 0s - loss: 0.2897 - accuracy: 0.8980 - 151ms/epoch - 5ms/step
#
# Точність мультикласової на тестовому наборі: 0.8980000019073486

# %%
# Функція для візуалізації процесу навчання
def plot_history(history):
    # Графіки точності
    plt.plot(history.history['accuracy'], label='Точність на тренувальному наборі')
    plt.plot(history.history['val_accuracy'], label='Точність на тестовому наборі')
    plt.xlabel('Епохи')
    plt.ylabel('Точність')
    plt.legend()
    plt.show()

    # Графіки втрат
    plt.plot(history.history['loss'], label='Втрати на тренувальному наборі')
    plt.plot(history.history['val_loss'], label='Втрати на тестовому наборі')
    plt.xlabel('Епохи')
    plt.ylabel('Втрати')
    plt.legend()
    plt.show()

# Візуалізація для бінарної класифікації
plot_history(history_binary)

# Візуалізація для мультикласової класифікації
plot_history(history_multiclass)

# %%
# четвертий шар
model_large_b = Sequential([
    Dense(64, input_dim=2, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

model_large_b.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_large_b.fit(X_binary_train, y_binary_train, epochs=50, batch_size=8, validation_data=(X_binary_test, y_binary_test))


model_large_m = Sequential([
    Dense(64, input_dim=2, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='softmax')
])

model_large_m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_large_m.fit(X_multiclass_train, y_multiclass_train, epochs=50, batch_size=8, validation_data=(X_multiclass_test, y_multiclass_test))
# Out:
# Epoch 1/50
# 500/500 [==============================] - 2s 2ms/step - loss: 0.3235 - accuracy: 0.8615 - val_loss: 0.2774 - val_accuracy: 0.8860
# Epoch 2/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2530 - accuracy: 0.8892 - val_loss: 0.2488 - val_accuracy: 0.9000
# Epoch 3/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2291 - accuracy: 0.9082 - val_loss: 0.2320 - val_accuracy: 0.9140
# Epoch 4/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2199 - accuracy: 0.9160 - val_loss: 0.2266 - val_accuracy: 0.9160
# Epoch 5/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2154 - accuracy: 0.9145 - val_loss: 0.2345 - val_accuracy: 0.9120
# Epoch 6/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2147 - accuracy: 0.9175 - val_loss: 0.2199 - val_accuracy: 0.9130
# Epoch 7/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2124 - accuracy: 0.9165 - val_loss: 0.2211 - val_accuracy: 0.9070
# Epoch 8/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2093 - accuracy: 0.9180 - val_loss: 0.2265 - val_accuracy: 0.9060
# Epoch 9/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2092 - accuracy: 0.9172 - val_loss: 0.2180 - val_accuracy: 0.9090
# Epoch 10/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2087 - accuracy: 0.9212 - val_loss: 0.2161 - val_accuracy: 0.9170
# Epoch 11/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2067 - accuracy: 0.9197 - val_loss: 0.2214 - val_accuracy: 0.9070
# Epoch 12/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2081 - accuracy: 0.9190 - val_loss: 0.2211 - val_accuracy: 0.9140
# Epoch 13/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2065 - accuracy: 0.9168 - val_loss: 0.2160 - val_accuracy: 0.9120
# Epoch 14/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2053 - accuracy: 0.9200 - val_loss: 0.2109 - val_accuracy: 0.9120
# Epoch 15/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2049 - accuracy: 0.9165 - val_loss: 0.2204 - val_accuracy: 0.9140
# Epoch 16/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2048 - accuracy: 0.9158 - val_loss: 0.2137 - val_accuracy: 0.9100
# Epoch 17/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2060 - accuracy: 0.9180 - val_loss: 0.2143 - val_accuracy: 0.9170
# Epoch 18/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2031 - accuracy: 0.9197 - val_loss: 0.2158 - val_accuracy: 0.9090
# Epoch 19/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2046 - accuracy: 0.9210 - val_loss: 0.2169 - val_accuracy: 0.9130
# Epoch 20/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2030 - accuracy: 0.9180 - val_loss: 0.2167 - val_accuracy: 0.9160
# Epoch 21/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2021 - accuracy: 0.9195 - val_loss: 0.2252 - val_accuracy: 0.9130
# Epoch 22/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2037 - accuracy: 0.9178 - val_loss: 0.2238 - val_accuracy: 0.9110
# Epoch 23/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2022 - accuracy: 0.9195 - val_loss: 0.2145 - val_accuracy: 0.9150
# Epoch 24/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2015 - accuracy: 0.9200 - val_loss: 0.2198 - val_accuracy: 0.9140
# Epoch 25/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2001 - accuracy: 0.9225 - val_loss: 0.2131 - val_accuracy: 0.9130
# Epoch 26/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2021 - accuracy: 0.9227 - val_loss: 0.2139 - val_accuracy: 0.9130
# Epoch 27/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1991 - accuracy: 0.9208 - val_loss: 0.2153 - val_accuracy: 0.9140
# Epoch 28/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2021 - accuracy: 0.9193 - val_loss: 0.2108 - val_accuracy: 0.9120
# Epoch 29/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2016 - accuracy: 0.9202 - val_loss: 0.2110 - val_accuracy: 0.9130
# Epoch 30/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2005 - accuracy: 0.9212 - val_loss: 0.2115 - val_accuracy: 0.9140
# Epoch 31/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1993 - accuracy: 0.9212 - val_loss: 0.2285 - val_accuracy: 0.9110
# Epoch 32/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1989 - accuracy: 0.9212 - val_loss: 0.2142 - val_accuracy: 0.9120
# Epoch 33/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2009 - accuracy: 0.9205 - val_loss: 0.2177 - val_accuracy: 0.9130
# Epoch 34/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2000 - accuracy: 0.9210 - val_loss: 0.2165 - val_accuracy: 0.9130
# Epoch 35/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2009 - accuracy: 0.9225 - val_loss: 0.2182 - val_accuracy: 0.9130
# Epoch 36/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1987 - accuracy: 0.9210 - val_loss: 0.2184 - val_accuracy: 0.9160
# Epoch 37/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1997 - accuracy: 0.9197 - val_loss: 0.2185 - val_accuracy: 0.9170
# Epoch 38/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1989 - accuracy: 0.9225 - val_loss: 0.2113 - val_accuracy: 0.9140
# Epoch 39/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1976 - accuracy: 0.9225 - val_loss: 0.2185 - val_accuracy: 0.9140
# Epoch 40/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1994 - accuracy: 0.9215 - val_loss: 0.2134 - val_accuracy: 0.9120
# Epoch 41/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1980 - accuracy: 0.9222 - val_loss: 0.2166 - val_accuracy: 0.9120
# Epoch 42/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1991 - accuracy: 0.9220 - val_loss: 0.2093 - val_accuracy: 0.9120
# Epoch 43/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1982 - accuracy: 0.9208 - val_loss: 0.2139 - val_accuracy: 0.9150
# Epoch 44/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1984 - accuracy: 0.9230 - val_loss: 0.2193 - val_accuracy: 0.9150
# Epoch 45/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1972 - accuracy: 0.9222 - val_loss: 0.2131 - val_accuracy: 0.9140
# Epoch 46/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1977 - accuracy: 0.9243 - val_loss: 0.2144 - val_accuracy: 0.9120
# Epoch 47/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1956 - accuracy: 0.9252 - val_loss: 0.2191 - val_accuracy: 0.9110
# Epoch 48/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1972 - accuracy: 0.9235 - val_loss: 0.2136 - val_accuracy: 0.9110
# Epoch 49/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1981 - accuracy: 0.9225 - val_loss: 0.2132 - val_accuracy: 0.9160
# Epoch 50/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1968 - accuracy: 0.9225 - val_loss: 0.2124 - val_accuracy: 0.9160
# Epoch 1/50
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13684/1284215893.py in <module>
#      19
#      20 model_large_m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# ---> 21 model_large_m.fit(X_multiclass_train, y_multiclass_train, epochs=50, batch_size=8, validation_data=(X_multiclass_test, y_multiclass_test))
#
# ~\anaconda3\lib\site-packages\keras\src\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58         for t in inputs
#      59     ]
# ---> 60     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                         inputs, attrs, num_outputs)
#      62   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits defined at (most recent call last):
#   File "C:\Users\annbu\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#   File "C:\Users\annbu\anaconda3\lib\runpy.py", line 87, in _run_code
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#
#   File "C:\Users\annbu\anaconda3\lib\asyncio\base_events.py", line 596, in run_forever
#
#   File "C:\Users\annbu\anaconda3\lib\asyncio\base_events.py", line 1890, in _run_once
#
#   File "C:\Users\annbu\anaconda3\lib\asyncio\events.py", line 80, in _run
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 457, in dispatch_queue
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 446, in process_one
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 353, in dispatch_shell
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 648, in execute_request
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 353, in do_execute
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2901, in run_cell
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2947, in _run_cell
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3172, in run_cell_async
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#
#   File "C:\Users\annbu\AppData\Local\Temp/ipykernel_13684/1284215893.py", line 21, in <module>
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\engine\training.py", line 1783, in fit
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\engine\training.py", line 1377, in train_function
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\engine\training.py", line 1360, in step_function
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\engine\training.py", line 1349, in run_step
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\engine\training.py", line 1127, in train_step
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\engine\training.py", line 1185, in compute_loss
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\engine\compile_utils.py", line 277, in __call__
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\losses.py", line 143, in __call__
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\losses.py", line 270, in call
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\losses.py", line 2454, in sparse_categorical_crossentropy
#
#   File "C:\Users\annbu\anaconda3\lib\site-packages\keras\src\backend.py", line 5777, in sparse_categorical_crossentropy
#
# Received a label value of 2 which is outside the valid range of [0, 1).  Label values: 0 2 0 1 2 2 1 1
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]] [Op:__inference_train_function_4084539]

# %%
# оцінка ефективності моделі на тестовому наборі
test_loss, test_acc = model_large_b.evaluate(X_binary_test, y_binary_test, verbose=2)
print('\nТочність бінарної на тестовому наборі:', test_acc, '\n')

test_loss, test_acc = model_large_m.evaluate(X_multiclass_test, y_multiclass_test, verbose=2)
print('\nТочність мультикласової на тестовому наборі:', test_acc)

# %%
# Збільшення кількості нейронів у кожному шарі
model_more_neurons_b = Sequential([
    Dense(64, input_dim=2, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

model_more_neurons_b.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_more_neurons_b.fit(X_binary_train, y_binary_train, epochs=50, batch_size=8, validation_data=(X_binary_test, y_binary_test))


model_more_neurons_m = Sequential([
    Dense(64, input_dim=2, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='softmax')
])

model_more_neurons_m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_more_neurons_m.fit(X_multiclass_train, y_multiclass_train, epochs=50, batch_size=8, validation_data=(X_multiclass_test, y_multiclass_test))

# %%
# оцінка ефективності моделі на тестовому наборі
test_loss, test_acc = model_more_neurons_b.evaluate(X_binary_test, y_binary_test, verbose=2)
print('\nТочність бінарної на тестовому наборі:', test_acc, '\n')

test_loss, test_acc = model_more_neurons_m.evaluate(X_multiclass_test, y_multiclass_test, verbose=2)
print('\nТочність мультикласової на тестовому наборі:', test_acc)

# %%
# Використання оптимізатора Adam з callback
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * np.exp(-0.1)

callback = LearningRateScheduler(scheduler)

model_adam_callback_b = Sequential([
    Dense(32, input_dim=2, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

model_adam_callback_b.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_adam_callback_b.fit(X_binary_train, y_binary_train, epochs=50, batch_size=8, validation_data=(X_binary_test, y_binary_test), callbacks=[callback])


model_adam_callback_m = Sequential([
    Dense(32, input_dim=2, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

model_adam_callback_m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_adam_callback_m.fit(X_multiclass_train, y_multiclass_train, epochs=50, batch_size=8, validation_data=(X_multiclass_test, y_multiclass_test), callbacks=[callback])

# %%
# оцінка ефективності моделі на тестовому наборі
test_loss, test_acc = model_adam_callback_b.evaluate(X_binary_test, y_binary_test, verbose=2)
print('\nТочність бінарної на тестовому наборі:', test_acc, '\n')

test_loss, test_acc = model_adam_callback_m.evaluate(X_multiclass_test, y_multiclass_test, verbose=2)
print('\nТочність мультикласової на тестовому наборі:', test_acc)

# %%
# Тестування моделі при тренуванні протягом 300 епох
model_binary.fit(X_binary_train, y_binary_train, epochs=300, batch_size=8, validation_data=(X_binary_test, y_binary_test))

model_multiclass.fit(X_multiclass_train, y_multiclass_train, epochs=300, batch_size=8, validation_data=(X_multiclass_test, y_multiclass_test))

# %%
# оцінка ефективності моделі на тестовому наборі
test_loss, test_acc = model_binary.evaluate(X_binary_test, y_binary_test, verbose=2)
print('\nТочність бінарної на тестовому наборі:', test_acc, '\n')

test_loss, test_acc = model_multiclass.evaluate(X_multiclass_test, y_multiclass_test, verbose=2)
print('\nТочність мультикласової на тестовому наборі:', test_acc)
